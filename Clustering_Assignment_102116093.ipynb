# %%
# !pip install pycaret &> /dev/null
print("Pycaret installed sucessfully")
# Out:
# Pycaret installed sucessfully

# %%
import pandas as pd
data=pd.read_csv('/content/Wholesale customers data.csv')

# %%
data.head()
# Out:
#    Channel  Region  Fresh  Milk  Grocery  Frozen  Detergents_Paper  Delicassen
# 0        2       3  12669  9656     7561     214              2674        1338
# 1        2       3   7057  9810     9568    1762              3293        1776
# 2        2       3   6353  8808     7684    2405              3516        7844
# 3        1       3  13265  1196     4221    6404               507        1788
# 4        2       3  22615  5410     7198    3915              1777        5185

# %%
from pycaret.clustering import *

kMeanClusteringParameters = setup(data, verbose=False)
KMeanClusteringModel = create_model('kmeans', num_clusters=4)
kMeanPrediction = assign_model(KMeanClusteringModel)
kMeanPrediction
# Out:
# <style type="text/css">
# </style>
# <table id="T_48566" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_48566_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_48566_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_48566_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_48566_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_48566_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_48566_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_48566_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_48566_row0_col0" class="data row0 col0" >0.4144</td>
#       <td id="T_48566_row0_col1" class="data row0 col1" >206.4566</td>
#       <td id="T_48566_row0_col2" class="data row0 col2" >0.8648</td>
#       <td id="T_48566_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_48566_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_48566_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
#      Channel  Region  Fresh   Milk  Grocery  Frozen  Detergents_Paper  \
# 0          2       3  12669   9656     7561     214              2674
# 1          2       3   7057   9810     9568    1762              3293
# 2          2       3   6353   8808     7684    2405              3516
# 3          1       3  13265   1196     4221    6404               507
# 4          2       3  22615   5410     7198    3915              1777
# ..       ...     ...    ...    ...      ...     ...               ...
# 435        1       3  29703  12051    16027   13135               182
# 436        1       3  39228   1431      764    4510                93
# 437        2       3  14531  15488    30243     437             14841
# 438        1       3  10290   1981     2232    1038               168
# 439        1       3   2787   1698     2510      65               477
#
#      Delicassen    Cluster
# 0          1338  Cluster 0
# 1          1776  Cluster 0
# 2          7844  Cluster 0
# 3          1788  Cluster 0
# 4          5185  Cluster 1
# ..          ...        ...
# 435        2204  Cluster 1
# 436        2346  Cluster 1
# 437        1867  Cluster 3
# 438        2125  Cluster 0
# 439          52  Cluster 0
#
# [440 rows x 9 columns]

# %%
plot_model(KMeanClusteringModel, plot = 'elbow')

# %%
#No Data Preprocessing

import pandas as pd
setup(data = data, verbose=False)

print("For Cluster = 3")
x = create_model('kmeans', num_clusters = 3)

print("For Cluster = 4")
x = create_model('kmeans', num_clusters = 4)

print("For Cluster = 5")
x = create_model('kmeans', num_clusters = 5)
# Out:
# For Cluster = 3
# <style type="text/css">
# </style>
# <table id="T_0c42e" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0c42e_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_0c42e_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_0c42e_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_0c42e_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_0c42e_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_0c42e_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0c42e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_0c42e_row0_col0" class="data row0 col0" >0.4784</td>
#       <td id="T_0c42e_row0_col1" class="data row0 col1" >210.1526</td>
#       <td id="T_0c42e_row0_col2" class="data row0 col2" >0.8895</td>
#       <td id="T_0c42e_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_0c42e_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_0c42e_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# For Cluster = 4
# <style type="text/css">
# </style>
# <table id="T_61276" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_61276_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_61276_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_61276_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_61276_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_61276_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_61276_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_61276_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_61276_row0_col0" class="data row0 col0" >0.4144</td>
#       <td id="T_61276_row0_col1" class="data row0 col1" >206.4566</td>
#       <td id="T_61276_row0_col2" class="data row0 col2" >0.8648</td>
#       <td id="T_61276_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_61276_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_61276_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# For Cluster = 5
# <style type="text/css">
# </style>
# <table id="T_dea58" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_dea58_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_dea58_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_dea58_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_dea58_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_dea58_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_dea58_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_dea58_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_dea58_row0_col0" class="data row0 col0" >0.3690</td>
#       <td id="T_dea58_row0_col1" class="data row0 col1" >213.9071</td>
#       <td id="T_dea58_row0_col2" class="data row0 col2" >0.8906</td>
#       <td id="T_dea58_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_dea58_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_dea58_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]

# %%
#Using Normalization
setup(data=data ,normalize=True, normalize_method='zscore',verbose=False)

print("For cluster=3")
x=create_model('kmeans',num_clusters=3)

print("For cluster=4")
x=create_model('kmeans',num_clusters=4)

print("For cluster=5")
x=create_model('kmeans',num_clusters=5)

print("For cluster=6")
x=create_model('kmeans',num_clusters=6)
# Out:
# For cluster=3
# <style type="text/css">
# </style>
# <table id="T_14320" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_14320_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_14320_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_14320_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_14320_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_14320_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_14320_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_14320_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_14320_row0_col0" class="data row0 col0" >0.3568</td>
#       <td id="T_14320_row0_col1" class="data row0 col1" >139.3494</td>
#       <td id="T_14320_row0_col2" class="data row0 col2" >1.1736</td>
#       <td id="T_14320_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_14320_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_14320_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# For cluster=4
# <style type="text/css">
# </style>
# <table id="T_c5c37" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c5c37_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_c5c37_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_c5c37_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_c5c37_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_c5c37_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_c5c37_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c5c37_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c5c37_row0_col0" class="data row0 col0" >0.3482</td>
#       <td id="T_c5c37_row0_col1" class="data row0 col1" >130.9179</td>
#       <td id="T_c5c37_row0_col2" class="data row0 col2" >1.2359</td>
#       <td id="T_c5c37_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_c5c37_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_c5c37_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# For cluster=5
# <style type="text/css">
# </style>
# <table id="T_a1d4d" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a1d4d_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_a1d4d_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_a1d4d_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_a1d4d_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_a1d4d_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_a1d4d_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a1d4d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a1d4d_row0_col0" class="data row0 col0" >0.3503</td>
#       <td id="T_a1d4d_row0_col1" class="data row0 col1" >139.6243</td>
#       <td id="T_a1d4d_row0_col2" class="data row0 col2" >1.1441</td>
#       <td id="T_a1d4d_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_a1d4d_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_a1d4d_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# For cluster=6
# <style type="text/css">
# </style>
# <table id="T_5ad3e" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5ad3e_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_5ad3e_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_5ad3e_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_5ad3e_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_5ad3e_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_5ad3e_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5ad3e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_5ad3e_row0_col0" class="data row0 col0" >0.3516</td>
#       <td id="T_5ad3e_row0_col1" class="data row0 col1" >145.7303</td>
#       <td id="T_5ad3e_row0_col2" class="data row0 col2" >0.9620</td>
#       <td id="T_5ad3e_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_5ad3e_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_5ad3e_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]

# %%
setup(data = data, normalize = True, normalize_method = 'zscore', verbose=False)
x = create_model('kmeans')
plot_model(x, plot = 'elbow')
# Out:
# <style type="text/css">
# </style>
# <table id="T_e035e" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e035e_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_e035e_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_e035e_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_e035e_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_e035e_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_e035e_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e035e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e035e_row0_col0" class="data row0 col0" >0.3478</td>
#       <td id="T_e035e_row0_col1" class="data row0 col1" >130.9300</td>
#       <td id="T_e035e_row0_col2" class="data row0 col2" >1.2377</td>
#       <td id="T_e035e_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_e035e_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_e035e_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]

# %%
#Model Performance using Transformation

setup(data=data,transformation=True,transformation_method='yeo-johnson',verbose=False)
x=create_model('kmeans')
plot_model(x,plot='elbow')
# Out:
# <style type="text/css">
# </style>
# <table id="T_f922f" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f922f_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_f922f_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_f922f_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_f922f_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_f922f_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_f922f_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f922f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f922f_row0_col0" class="data row0 col0" >0.5181</td>
#       <td id="T_f922f_row0_col1" class="data row0 col1" >15162.6315</td>
#       <td id="T_f922f_row0_col2" class="data row0 col2" >0.6203</td>
#       <td id="T_f922f_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_f922f_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_f922f_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]

# %%
setup(data = data, transformation = True, transformation_method = 'yeo-johnson', verbose=False)

print("For Cluster = 3")
x = create_model('kmeans', num_clusters = 3)

print("For Cluster = 4")
x = create_model('kmeans', num_clusters = 4)

print("For Cluster = 5")
x = create_model('kmeans', num_clusters = 5)
# Out:
# For Cluster = 3
# <style type="text/css">
# </style>
# <table id="T_0a4db" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0a4db_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_0a4db_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_0a4db_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_0a4db_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_0a4db_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_0a4db_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0a4db_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_0a4db_row0_col0" class="data row0 col0" >0.8554</td>
#       <td id="T_0a4db_row0_col1" class="data row0 col1" >13039.7633</td>
#       <td id="T_0a4db_row0_col2" class="data row0 col2" >0.3389</td>
#       <td id="T_0a4db_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_0a4db_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_0a4db_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# For Cluster = 4
# <style type="text/css">
# </style>
# <table id="T_e6bac" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e6bac_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_e6bac_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_e6bac_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_e6bac_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_e6bac_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_e6bac_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e6bac_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e6bac_row0_col0" class="data row0 col0" >0.5181</td>
#       <td id="T_e6bac_row0_col1" class="data row0 col1" >15162.6315</td>
#       <td id="T_e6bac_row0_col2" class="data row0 col2" >0.6203</td>
#       <td id="T_e6bac_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_e6bac_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_e6bac_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# For Cluster = 5
# <style type="text/css">
# </style>
# <table id="T_ef314" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ef314_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_ef314_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_ef314_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_ef314_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_ef314_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_ef314_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ef314_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ef314_row0_col0" class="data row0 col0" >0.4620</td>
#       <td id="T_ef314_row0_col1" class="data row0 col1" >14221.6229</td>
#       <td id="T_ef314_row0_col2" class="data row0 col2" >0.7017</td>
#       <td id="T_ef314_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_ef314_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_ef314_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]

# %%
#Model Performance using PCA

setup(data=data,pca=True,pca_method='linear',verbose=False)
x=create_model('kmeans')
plot_model(x,plot='elbow')
# Out:
# <style type="text/css">
# </style>
# <table id="T_63a81" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_63a81_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_63a81_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_63a81_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_63a81_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_63a81_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_63a81_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_63a81_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_63a81_row0_col0" class="data row0 col0" >0.3956</td>
#       <td id="T_63a81_row0_col1" class="data row0 col1" >207.8186</td>
#       <td id="T_63a81_row0_col2" class="data row0 col2" >0.9040</td>
#       <td id="T_63a81_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_63a81_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_63a81_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]

# %%
setup(data = data, pca = True, pca_method = 'linear', verbose=False)

print("For Cluster = 3")
x = create_model('kmeans', num_clusters = 3)

print("For Cluster = 4")
x = create_model('kmeans', num_clusters = 4)

print("For Cluster = 5")
x = create_model('kmeans', num_clusters = 5)
# Out:
# For Cluster = 3
# <style type="text/css">
# </style>
# <table id="T_0c0a0" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0c0a0_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_0c0a0_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_0c0a0_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_0c0a0_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_0c0a0_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_0c0a0_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0c0a0_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_0c0a0_row0_col0" class="data row0 col0" >0.4784</td>
#       <td id="T_0c0a0_row0_col1" class="data row0 col1" >210.1526</td>
#       <td id="T_0c0a0_row0_col2" class="data row0 col2" >0.8895</td>
#       <td id="T_0c0a0_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_0c0a0_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_0c0a0_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# For Cluster = 4
# <style type="text/css">
# </style>
# <table id="T_22d4c" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_22d4c_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_22d4c_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_22d4c_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_22d4c_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_22d4c_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_22d4c_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_22d4c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_22d4c_row0_col0" class="data row0 col0" >0.3866</td>
#       <td id="T_22d4c_row0_col1" class="data row0 col1" >207.8197</td>
#       <td id="T_22d4c_row0_col2" class="data row0 col2" >0.9543</td>
#       <td id="T_22d4c_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_22d4c_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_22d4c_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# For Cluster = 5
# <style type="text/css">
# </style>
# <table id="T_6878d" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6878d_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_6878d_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_6878d_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_6878d_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_6878d_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_6878d_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6878d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_6878d_row0_col0" class="data row0 col0" >0.3884</td>
#       <td id="T_6878d_row0_col1" class="data row0 col1" >214.2761</td>
#       <td id="T_6878d_row0_col2" class="data row0 col2" >0.8841</td>
#       <td id="T_6878d_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_6878d_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_6878d_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]

# %%
#Model performance using Transformation + Normalization

setup(data=data,transformation=True,normalize=True,normalize_method='zscore',transformation_method='yeo-johnson',verbose=False)
x=create_model('kmeans')
plot_model(x,plot='elbow')
# Out:
# <style type="text/css">
# </style>
# <table id="T_a5c21" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a5c21_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_a5c21_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_a5c21_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_a5c21_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_a5c21_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_a5c21_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a5c21_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a5c21_row0_col0" class="data row0 col0" >0.2476</td>
#       <td id="T_a5c21_row0_col1" class="data row0 col1" >136.3494</td>
#       <td id="T_a5c21_row0_col2" class="data row0 col2" >1.4215</td>
#       <td id="T_a5c21_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_a5c21_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_a5c21_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]

# %%
setup(data = data, transformation = True, normalize = True,
      normalize_method = 'zscore', transformation_method = 'yeo-johnson', verbose=False)

print("For Cluster = 3")
x = create_model('kmeans', num_clusters = 3)

print("For Cluster = 4")
x = create_model('kmeans', num_clusters = 4)

print("For Cluster = 5")
x = create_model('kmeans', num_clusters = 5)
# Out:
# For Cluster = 3
# <style type="text/css">
# </style>
# <table id="T_e0864" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e0864_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_e0864_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_e0864_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_e0864_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_e0864_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_e0864_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e0864_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e0864_row0_col0" class="data row0 col0" >0.2228</td>
#       <td id="T_e0864_row0_col1" class="data row0 col1" >153.5484</td>
#       <td id="T_e0864_row0_col2" class="data row0 col2" >1.6406</td>
#       <td id="T_e0864_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_e0864_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_e0864_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# For Cluster = 4
# <style type="text/css">
# </style>
# <table id="T_40aa5" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_40aa5_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_40aa5_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_40aa5_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_40aa5_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_40aa5_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_40aa5_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_40aa5_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_40aa5_row0_col0" class="data row0 col0" >0.2472</td>
#       <td id="T_40aa5_row0_col1" class="data row0 col1" >136.3349</td>
#       <td id="T_40aa5_row0_col2" class="data row0 col2" >1.4208</td>
#       <td id="T_40aa5_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_40aa5_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_40aa5_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# For Cluster = 5
# <style type="text/css">
# </style>
# <table id="T_7535a" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7535a_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_7535a_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_7535a_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_7535a_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_7535a_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_7535a_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7535a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_7535a_row0_col0" class="data row0 col0" >0.2184</td>
#       <td id="T_7535a_row0_col1" class="data row0 col1" >121.2396</td>
#       <td id="T_7535a_row0_col2" class="data row0 col2" >1.5850</td>
#       <td id="T_7535a_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_7535a_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_7535a_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]

# %%
#Using T+N+PCA

setup(data=data,transformation=True,normalize=True,pca=True,normalize_method='zscore',transformation_method='yeo-johnson',pca_method='linear',verbose=False)
x=create_model('kmeans')
plot_model(x,plot='elbow')
# Out:
# <style type="text/css">
# </style>
# <table id="T_2e8d5" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2e8d5_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_2e8d5_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_2e8d5_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_2e8d5_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_2e8d5_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_2e8d5_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2e8d5_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_2e8d5_row0_col0" class="data row0 col0" >0.2472</td>
#       <td id="T_2e8d5_row0_col1" class="data row0 col1" >136.3349</td>
#       <td id="T_2e8d5_row0_col2" class="data row0 col2" >1.4208</td>
#       <td id="T_2e8d5_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_2e8d5_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_2e8d5_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]

# %%
setup(data = data, transformation = True, normalize = True, pca = True,
      normalize_method = 'zscore',
      transformation_method = 'yeo-johnson',
      pca_method = 'linear', verbose=False)

print("For Cluster = 3")
x = create_model('kmeans', num_clusters = 3)

print("For Cluster = 4")
x = create_model('kmeans', num_clusters = 4)

print("For Cluster = 5")
x = create_model('kmeans', num_clusters = 5)
# Out:
# For Cluster = 3
# <style type="text/css">
# </style>
# <table id="T_3399b" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3399b_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_3399b_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_3399b_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_3399b_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_3399b_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_3399b_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3399b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_3399b_row0_col0" class="data row0 col0" >0.2228</td>
#       <td id="T_3399b_row0_col1" class="data row0 col1" >153.5484</td>
#       <td id="T_3399b_row0_col2" class="data row0 col2" >1.6406</td>
#       <td id="T_3399b_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_3399b_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_3399b_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# For Cluster = 4
# <style type="text/css">
# </style>
# <table id="T_176a7" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_176a7_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_176a7_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_176a7_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_176a7_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_176a7_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_176a7_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_176a7_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_176a7_row0_col0" class="data row0 col0" >0.2472</td>
#       <td id="T_176a7_row0_col1" class="data row0 col1" >136.3349</td>
#       <td id="T_176a7_row0_col2" class="data row0 col2" >1.4208</td>
#       <td id="T_176a7_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_176a7_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_176a7_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# For Cluster = 5
# <style type="text/css">
# </style>
# <table id="T_2f235" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2f235_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_2f235_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_2f235_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_2f235_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_2f235_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_2f235_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2f235_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_2f235_row0_col0" class="data row0 col0" >0.2132</td>
#       <td id="T_2f235_row0_col1" class="data row0 col1" >120.4345</td>
#       <td id="T_2f235_row0_col2" class="data row0 col2" >1.6139</td>
#       <td id="T_2f235_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_2f235_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_2f235_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]

# %%
#Using Hierarchical Clustering

# %%
setup(data=data,verbose=False)
x=create_model('hclust')
plot_model(x,plot='elbow')
# Out:
# <style type="text/css">
# </style>
# <table id="T_e56a4" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e56a4_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_e56a4_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_e56a4_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_e56a4_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_e56a4_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_e56a4_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e56a4_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e56a4_row0_col0" class="data row0 col0" >0.3483</td>
#       <td id="T_e56a4_row0_col1" class="data row0 col1" >185.2559</td>
#       <td id="T_e56a4_row0_col2" class="data row0 col2" >0.9701</td>
#       <td id="T_e56a4_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_e56a4_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_e56a4_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]

# %%
hModel=create_model('hclust',num_clusters=3)
hModelPrediction=assign_model(hModel)
hModelPrediction
# Out:
# <style type="text/css">
# </style>
# <table id="T_e8790" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e8790_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_e8790_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_e8790_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_e8790_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_e8790_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_e8790_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e8790_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e8790_row0_col0" class="data row0 col0" >0.3750</td>
#       <td id="T_e8790_row0_col1" class="data row0 col1" >183.3597</td>
#       <td id="T_e8790_row0_col2" class="data row0 col2" >0.9783</td>
#       <td id="T_e8790_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_e8790_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_e8790_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
#      Channel  Region  Fresh   Milk  Grocery  Frozen  Detergents_Paper  \
# 0          2       3  12669   9656     7561     214              2674
# 1          2       3   7057   9810     9568    1762              3293
# 2          2       3   6353   8808     7684    2405              3516
# 3          1       3  13265   1196     4221    6404               507
# 4          2       3  22615   5410     7198    3915              1777
# ..       ...     ...    ...    ...      ...     ...               ...
# 435        1       3  29703  12051    16027   13135               182
# 436        1       3  39228   1431      764    4510                93
# 437        2       3  14531  15488    30243     437             14841
# 438        1       3  10290   1981     2232    1038               168
# 439        1       3   2787   1698     2510      65               477
#
#      Delicassen    Cluster
# 0          1338  Cluster 2
# 1          1776  Cluster 2
# 2          7844  Cluster 2
# 3          1788  Cluster 2
# 4          5185  Cluster 0
# ..          ...        ...
# 435        2204  Cluster 0
# 436        2346  Cluster 0
# 437        1867  Cluster 1
# 438        2125  Cluster 2
# 439          52  Cluster 2
#
# [440 rows x 9 columns]

# %%
evaluate_model(hModel)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
#No data Preprocessing
plot_model(hModel,plot='elbow')

# %%
setup(data=data,verbose=False)

print("For Cluster = 3")
x = create_model('hclust', num_clusters = 3)

print("For Cluster = 4")
x = create_model('hclust', num_clusters = 4)

print("For Cluster = 5")
x = create_model('hclust', num_clusters = 5)
# Out:
# For Cluster = 3
# <style type="text/css">
# </style>
# <table id="T_f6769" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f6769_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_f6769_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_f6769_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_f6769_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_f6769_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_f6769_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f6769_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f6769_row0_col0" class="data row0 col0" >0.3750</td>
#       <td id="T_f6769_row0_col1" class="data row0 col1" >183.3597</td>
#       <td id="T_f6769_row0_col2" class="data row0 col2" >0.9783</td>
#       <td id="T_f6769_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_f6769_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_f6769_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# For Cluster = 4
# <style type="text/css">
# </style>
# <table id="T_f9ec5" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f9ec5_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_f9ec5_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_f9ec5_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_f9ec5_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_f9ec5_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_f9ec5_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f9ec5_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f9ec5_row0_col0" class="data row0 col0" >0.3483</td>
#       <td id="T_f9ec5_row0_col1" class="data row0 col1" >185.2559</td>
#       <td id="T_f9ec5_row0_col2" class="data row0 col2" >0.9701</td>
#       <td id="T_f9ec5_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_f9ec5_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_f9ec5_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# For Cluster = 5
# <style type="text/css">
# </style>
# <table id="T_949de" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_949de_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_949de_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_949de_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_949de_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_949de_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_949de_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_949de_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_949de_row0_col0" class="data row0 col0" >0.3522</td>
#       <td id="T_949de_row0_col1" class="data row0 col1" >196.9540</td>
#       <td id="T_949de_row0_col2" class="data row0 col2" >0.9106</td>
#       <td id="T_949de_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_949de_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_949de_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]

# %%
#Using Normalization

setup(data=data,normalize=True,normalize_method='zscore',verbose=False)
x=create_model('hclust')
plot_model(x,plot='elbow')
# Out:
# <style type="text/css">
# </style>
# <table id="T_b356b" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b356b_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_b356b_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_b356b_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_b356b_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_b356b_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_b356b_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b356b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b356b_row0_col0" class="data row0 col0" >0.3623</td>
#       <td id="T_b356b_row0_col1" class="data row0 col1" >120.7561</td>
#       <td id="T_b356b_row0_col2" class="data row0 col2" >0.8255</td>
#       <td id="T_b356b_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_b356b_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_b356b_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]

# %%
setup(data=data,normalize=True,normalize_method='zscore',verbose=False)

print("For Cluster = 3")
x = create_model('hclust', num_clusters = 3)

print("For Cluster = 4")
x = create_model('hclust', num_clusters = 4)

print("For Cluster = 5")
x = create_model('hclust', num_clusters = 5)

print("For Cluster = 6")
x = create_model('hclust', num_clusters = 6)
# Out:
# For Cluster = 3
# <style type="text/css">
# </style>
# <table id="T_41a49" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_41a49_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_41a49_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_41a49_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_41a49_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_41a49_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_41a49_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_41a49_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_41a49_row0_col0" class="data row0 col0" >0.3600</td>
#       <td id="T_41a49_row0_col1" class="data row0 col1" >126.2475</td>
#       <td id="T_41a49_row0_col2" class="data row0 col2" >1.1551</td>
#       <td id="T_41a49_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_41a49_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_41a49_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# For Cluster = 4
# <style type="text/css">
# </style>
# <table id="T_b9799" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b9799_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_b9799_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_b9799_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_b9799_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_b9799_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_b9799_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b9799_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b9799_row0_col0" class="data row0 col0" >0.3623</td>
#       <td id="T_b9799_row0_col1" class="data row0 col1" >120.7561</td>
#       <td id="T_b9799_row0_col2" class="data row0 col2" >0.8255</td>
#       <td id="T_b9799_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_b9799_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_b9799_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# For Cluster = 5
# <style type="text/css">
# </style>
# <table id="T_7f79a" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7f79a_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_7f79a_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_7f79a_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_7f79a_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_7f79a_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_7f79a_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7f79a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_7f79a_row0_col0" class="data row0 col0" >0.3178</td>
#       <td id="T_7f79a_row0_col1" class="data row0 col1" >123.5061</td>
#       <td id="T_7f79a_row0_col2" class="data row0 col2" >0.8960</td>
#       <td id="T_7f79a_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_7f79a_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_7f79a_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# For Cluster = 6
# <style type="text/css">
# </style>
# <table id="T_5e2bc" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5e2bc_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_5e2bc_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_5e2bc_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_5e2bc_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_5e2bc_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_5e2bc_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5e2bc_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_5e2bc_row0_col0" class="data row0 col0" >0.3438</td>
#       <td id="T_5e2bc_row0_col1" class="data row0 col1" >131.4186</td>
#       <td id="T_5e2bc_row0_col2" class="data row0 col2" >0.9554</td>
#       <td id="T_5e2bc_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_5e2bc_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_5e2bc_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]

# %%
#Using Transformation

setup(data = data, transformation = True, transformation_method = 'yeo-johnson', verbose=False)
x = create_model('hclust')
plot_model(x, plot = 'elbow')
# Out:
# <style type="text/css">
# </style>
# <table id="T_5c411" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5c411_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_5c411_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_5c411_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_5c411_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_5c411_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_5c411_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5c411_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_5c411_row0_col0" class="data row0 col0" >0.5109</td>
#       <td id="T_5c411_row0_col1" class="data row0 col1" >14291.9587</td>
#       <td id="T_5c411_row0_col2" class="data row0 col2" >0.6054</td>
#       <td id="T_5c411_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_5c411_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_5c411_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]

# %%
setup(data=data,transformation=True,transformation_method='yeo-johnson',verbose=False)

print("For Cluster = 3")
x = create_model('hclust', num_clusters = 3)

print("For Cluster = 4")
x = create_model('hclust', num_clusters = 4)

print("For Cluster = 5")
x = create_model('hclust', num_clusters = 5)
# Out:
# For Cluster = 3
# <style type="text/css">
# </style>
# <table id="T_3ad24" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3ad24_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_3ad24_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_3ad24_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_3ad24_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_3ad24_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_3ad24_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3ad24_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_3ad24_row0_col0" class="data row0 col0" >0.8554</td>
#       <td id="T_3ad24_row0_col1" class="data row0 col1" >13039.7633</td>
#       <td id="T_3ad24_row0_col2" class="data row0 col2" >0.3389</td>
#       <td id="T_3ad24_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_3ad24_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_3ad24_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# For Cluster = 4
# <style type="text/css">
# </style>
# <table id="T_f8933" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f8933_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_f8933_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_f8933_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_f8933_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_f8933_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_f8933_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f8933_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f8933_row0_col0" class="data row0 col0" >0.5109</td>
#       <td id="T_f8933_row0_col1" class="data row0 col1" >14291.9587</td>
#       <td id="T_f8933_row0_col2" class="data row0 col2" >0.6054</td>
#       <td id="T_f8933_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_f8933_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_f8933_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# For Cluster = 5
# <style type="text/css">
# </style>
# <table id="T_63835" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_63835_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_63835_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_63835_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_63835_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_63835_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_63835_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_63835_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_63835_row0_col0" class="data row0 col0" >0.4530</td>
#       <td id="T_63835_row0_col1" class="data row0 col1" >14101.6445</td>
#       <td id="T_63835_row0_col2" class="data row0 col2" >0.7125</td>
#       <td id="T_63835_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_63835_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_63835_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]

# %%
#Using PCA

setup(data = data, pca = True, pca_method = 'linear', verbose=False)
x = create_model('hclust')
plot_model(x, plot = 'elbow')
# Out:
# <style type="text/css">
# </style>
# <table id="T_5b259" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5b259_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_5b259_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_5b259_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_5b259_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_5b259_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_5b259_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5b259_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_5b259_row0_col0" class="data row0 col0" >0.3483</td>
#       <td id="T_5b259_row0_col1" class="data row0 col1" >185.2559</td>
#       <td id="T_5b259_row0_col2" class="data row0 col2" >0.9701</td>
#       <td id="T_5b259_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_5b259_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_5b259_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]

# %%
setup(data = data, pca = True, pca_method = 'linear', verbose=False)

print("For Cluster = 3")
x = create_model('hclust', num_clusters = 3)

print("For Cluster = 4")
x = create_model('hclust', num_clusters = 4)

print("For Cluster = 5")
x = create_model('hclust', num_clusters = 5)
# Out:
# For Cluster = 3
# <style type="text/css">
# </style>
# <table id="T_2fe73" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2fe73_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_2fe73_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_2fe73_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_2fe73_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_2fe73_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_2fe73_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2fe73_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_2fe73_row0_col0" class="data row0 col0" >0.3750</td>
#       <td id="T_2fe73_row0_col1" class="data row0 col1" >183.3597</td>
#       <td id="T_2fe73_row0_col2" class="data row0 col2" >0.9783</td>
#       <td id="T_2fe73_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_2fe73_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_2fe73_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# For Cluster = 4
# <style type="text/css">
# </style>
# <table id="T_404a9" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_404a9_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_404a9_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_404a9_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_404a9_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_404a9_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_404a9_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_404a9_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_404a9_row0_col0" class="data row0 col0" >0.3483</td>
#       <td id="T_404a9_row0_col1" class="data row0 col1" >185.2559</td>
#       <td id="T_404a9_row0_col2" class="data row0 col2" >0.9701</td>
#       <td id="T_404a9_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_404a9_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_404a9_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# For Cluster = 5
# <style type="text/css">
# </style>
# <table id="T_c94d9" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c94d9_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_c94d9_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_c94d9_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_c94d9_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_c94d9_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_c94d9_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c94d9_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c94d9_row0_col0" class="data row0 col0" >0.3522</td>
#       <td id="T_c94d9_row0_col1" class="data row0 col1" >196.9540</td>
#       <td id="T_c94d9_row0_col2" class="data row0 col2" >0.9106</td>
#       <td id="T_c94d9_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_c94d9_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_c94d9_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]

# %%
#Using T+N

setup(data=data,normalize=True,transformation=True,normalize_method='zscore',transformation_method='yeo-johnson',
      verbose=False)
x=create_model('hclust')
plot_model(x,plot='elbow')
# Out:
# <style type="text/css">
# </style>
# <table id="T_1a660" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1a660_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_1a660_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_1a660_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_1a660_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_1a660_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_1a660_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1a660_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_1a660_row0_col0" class="data row0 col0" >0.2425</td>
#       <td id="T_1a660_row0_col1" class="data row0 col1" >127.8460</td>
#       <td id="T_1a660_row0_col2" class="data row0 col2" >1.4576</td>
#       <td id="T_1a660_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_1a660_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_1a660_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]

# %%
setup(data=data,normalize=True,transformation=True,normalize_method='zscore',transformation_method='yeo-johnson',
      verbose=False)

print("For Cluster = 3")
x = create_model('hclust', num_clusters = 3)

print("For Cluster = 4")
x = create_model('hclust', num_clusters = 4)

print("For Cluster = 5")
x = create_model('hclust', num_clusters = 5)
# Out:
# For Cluster = 3
# <style type="text/css">
# </style>
# <table id="T_05494" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_05494_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_05494_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_05494_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_05494_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_05494_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_05494_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_05494_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_05494_row0_col0" class="data row0 col0" >0.2288</td>
#       <td id="T_05494_row0_col1" class="data row0 col1" >138.5574</td>
#       <td id="T_05494_row0_col2" class="data row0 col2" >1.5189</td>
#       <td id="T_05494_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_05494_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_05494_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# For Cluster = 4
# <style type="text/css">
# </style>
# <table id="T_185f8" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_185f8_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_185f8_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_185f8_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_185f8_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_185f8_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_185f8_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_185f8_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_185f8_row0_col0" class="data row0 col0" >0.2425</td>
#       <td id="T_185f8_row0_col1" class="data row0 col1" >127.8460</td>
#       <td id="T_185f8_row0_col2" class="data row0 col2" >1.4576</td>
#       <td id="T_185f8_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_185f8_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_185f8_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# For Cluster = 5
# <style type="text/css">
# </style>
# <table id="T_66f67" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_66f67_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_66f67_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_66f67_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_66f67_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_66f67_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_66f67_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_66f67_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_66f67_row0_col0" class="data row0 col0" >0.2073</td>
#       <td id="T_66f67_row0_col1" class="data row0 col1" >112.2108</td>
#       <td id="T_66f67_row0_col2" class="data row0 col2" >1.4930</td>
#       <td id="T_66f67_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_66f67_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_66f67_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]

# %%
#Using T+N+PCA

setup(data = data, transformation = True, normalize = True, pca = True,
      normalize_method = 'zscore', transformation_method = 'yeo-johnson',
      pca_method = 'linear', verbose=False)
x = create_model('hclust')
plot_model(x, plot = 'elbow')
# Out:
# <style type="text/css">
# </style>
# <table id="T_47fd1" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_47fd1_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_47fd1_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_47fd1_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_47fd1_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_47fd1_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_47fd1_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_47fd1_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_47fd1_row0_col0" class="data row0 col0" >0.2425</td>
#       <td id="T_47fd1_row0_col1" class="data row0 col1" >127.8460</td>
#       <td id="T_47fd1_row0_col2" class="data row0 col2" >1.4576</td>
#       <td id="T_47fd1_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_47fd1_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_47fd1_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]

# %%
setup(data=data,normalize=True,transformation=True,pca=True,pca_method='linear',normalize_method='zscore',transformation_method='yeo-johnson',
      verbose=False)

print("For Cluster = 3")
x = create_model('hclust', num_clusters = 3)

print("For Cluster = 4")
x = create_model('hclust', num_clusters = 4)

print("For Cluster = 5")
x = create_model('hclust', num_clusters = 5)
# Out:
# For Cluster = 3
# <style type="text/css">
# </style>
# <table id="T_608eb" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_608eb_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_608eb_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_608eb_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_608eb_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_608eb_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_608eb_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_608eb_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_608eb_row0_col0" class="data row0 col0" >0.2288</td>
#       <td id="T_608eb_row0_col1" class="data row0 col1" >138.5574</td>
#       <td id="T_608eb_row0_col2" class="data row0 col2" >1.5189</td>
#       <td id="T_608eb_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_608eb_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_608eb_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# For Cluster = 4
# <style type="text/css">
# </style>
# <table id="T_0b90a" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0b90a_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_0b90a_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_0b90a_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_0b90a_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_0b90a_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_0b90a_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0b90a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_0b90a_row0_col0" class="data row0 col0" >0.2425</td>
#       <td id="T_0b90a_row0_col1" class="data row0 col1" >127.8460</td>
#       <td id="T_0b90a_row0_col2" class="data row0 col2" >1.4576</td>
#       <td id="T_0b90a_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_0b90a_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_0b90a_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# For Cluster = 5
# <style type="text/css">
# </style>
# <table id="T_3234c" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3234c_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_3234c_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_3234c_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_3234c_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_3234c_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_3234c_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3234c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_3234c_row0_col0" class="data row0 col0" >0.2073</td>
#       <td id="T_3234c_row0_col1" class="data row0 col1" >112.2108</td>
#       <td id="T_3234c_row0_col2" class="data row0 col2" >1.4930</td>
#       <td id="T_3234c_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_3234c_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_3234c_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]

# %%
#Using K-Mean Shift Clustering

setup(data=data,verbose=False)
meanShiftModel=create_model('meanshift',num_clusters=3)
meanShiftPrediction=assign_model(meanShiftModel)
meanShiftPrediction
# Out:
# <style type="text/css">
# </style>
# <table id="T_300e9" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_300e9_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_300e9_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_300e9_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_300e9_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_300e9_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_300e9_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_300e9_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_300e9_row0_col0" class="data row0 col0" >0.3644</td>
#       <td id="T_300e9_row0_col1" class="data row0 col1" >54.7541</td>
#       <td id="T_300e9_row0_col2" class="data row0 col2" >0.5765</td>
#       <td id="T_300e9_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_300e9_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_300e9_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
#      Channel  Region  Fresh   Milk  Grocery  Frozen  Detergents_Paper  \
# 0          2       3  12669   9656     7561     214              2674
# 1          2       3   7057   9810     9568    1762              3293
# 2          2       3   6353   8808     7684    2405              3516
# 3          1       3  13265   1196     4221    6404               507
# 4          2       3  22615   5410     7198    3915              1777
# ..       ...     ...    ...    ...      ...     ...               ...
# 435        1       3  29703  12051    16027   13135               182
# 436        1       3  39228   1431      764    4510                93
# 437        2       3  14531  15488    30243     437             14841
# 438        1       3  10290   1981     2232    1038               168
# 439        1       3   2787   1698     2510      65               477
#
#      Delicassen     Cluster
# 0          1338   Cluster 0
# 1          1776   Cluster 0
# 2          7844   Cluster 0
# 3          1788   Cluster 0
# 4          5185   Cluster 0
# ..          ...         ...
# 435        2204  Cluster 11
# 436        2346   Cluster 0
# 437        1867   Cluster 7
# 438        2125   Cluster 0
# 439          52   Cluster 0
#
# [440 rows x 9 columns]

# %%
#No data Preprocessing

setup(data = data, verbose=False)

print("For Cluster = 3")
x = create_model('meanshift', num_clusters = 3)

print("For Cluster = 4")
x = create_model('meanshift', num_clusters = 4)

print("For Cluster = 5")
x = create_model('meanshift', num_clusters = 5)
# Out:
# For Cluster = 3
# <style type="text/css">
# </style>
# <table id="T_a600f" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a600f_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_a600f_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_a600f_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_a600f_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_a600f_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_a600f_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a600f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a600f_row0_col0" class="data row0 col0" >0.3644</td>
#       <td id="T_a600f_row0_col1" class="data row0 col1" >54.7541</td>
#       <td id="T_a600f_row0_col2" class="data row0 col2" >0.5765</td>
#       <td id="T_a600f_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_a600f_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_a600f_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# For Cluster = 4
# <style type="text/css">
# </style>
# <table id="T_2d954" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2d954_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_2d954_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_2d954_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_2d954_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_2d954_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_2d954_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2d954_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_2d954_row0_col0" class="data row0 col0" >0.3644</td>
#       <td id="T_2d954_row0_col1" class="data row0 col1" >54.7541</td>
#       <td id="T_2d954_row0_col2" class="data row0 col2" >0.5765</td>
#       <td id="T_2d954_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_2d954_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_2d954_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# For Cluster = 5
# <style type="text/css">
# </style>
# <table id="T_d9b9b" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d9b9b_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_d9b9b_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_d9b9b_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_d9b9b_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_d9b9b_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_d9b9b_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d9b9b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d9b9b_row0_col0" class="data row0 col0" >0.3644</td>
#       <td id="T_d9b9b_row0_col1" class="data row0 col1" >54.7541</td>
#       <td id="T_d9b9b_row0_col2" class="data row0 col2" >0.5765</td>
#       <td id="T_d9b9b_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_d9b9b_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_d9b9b_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]

# %%
#Using Normalization

setup(data = data, normalize = True, normalize_method = 'zscore', verbose=False)

print("For Cluster = 3")
x = create_model('meanshift', num_clusters = 3)

print("For Cluster = 4")
x = create_model('meanshift', num_clusters = 4)

print("For Cluster = 5")
x = create_model('meanshift', num_clusters = 5)
# Out:
# For Cluster = 3
# <style type="text/css">
# </style>
# <table id="T_fdab2" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fdab2_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_fdab2_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_fdab2_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_fdab2_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_fdab2_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_fdab2_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fdab2_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_fdab2_row0_col0" class="data row0 col0" >0.4054</td>
#       <td id="T_fdab2_row0_col1" class="data row0 col1" >30.8599</td>
#       <td id="T_fdab2_row0_col2" class="data row0 col2" >0.4229</td>
#       <td id="T_fdab2_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_fdab2_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_fdab2_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# For Cluster = 4
# <style type="text/css">
# </style>
# <table id="T_9de4f" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9de4f_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_9de4f_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_9de4f_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_9de4f_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_9de4f_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_9de4f_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9de4f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_9de4f_row0_col0" class="data row0 col0" >0.4054</td>
#       <td id="T_9de4f_row0_col1" class="data row0 col1" >30.8599</td>
#       <td id="T_9de4f_row0_col2" class="data row0 col2" >0.4229</td>
#       <td id="T_9de4f_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_9de4f_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_9de4f_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# For Cluster = 5
# <style type="text/css">
# </style>
# <table id="T_0677b" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0677b_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_0677b_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_0677b_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_0677b_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_0677b_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_0677b_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0677b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_0677b_row0_col0" class="data row0 col0" >0.4054</td>
#       <td id="T_0677b_row0_col1" class="data row0 col1" >30.8599</td>
#       <td id="T_0677b_row0_col2" class="data row0 col2" >0.4229</td>
#       <td id="T_0677b_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_0677b_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_0677b_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]

# %%
#Using Transformation

setup(data = data, transformation = True, transformation_method = 'yeo-johnson', verbose=False)

print("For Cluster = 3")
x = create_model('meanshift', num_clusters = 3)

print("For Cluster = 4")
x = create_model('meanshift', num_clusters = 4)

print("For Cluster = 5")
x = create_model('meanshift', num_clusters = 5)
# Out:
# For Cluster = 3
# <style type="text/css">
# </style>
# <table id="T_29f65" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_29f65_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_29f65_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_29f65_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_29f65_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_29f65_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_29f65_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_29f65_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_29f65_row0_col0" class="data row0 col0" >0.9076</td>
#       <td id="T_29f65_row0_col1" class="data row0 col1" >14114.2429</td>
#       <td id="T_29f65_row0_col2" class="data row0 col2" >0.1625</td>
#       <td id="T_29f65_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_29f65_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_29f65_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# For Cluster = 4
# <style type="text/css">
# </style>
# <table id="T_a15db" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a15db_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_a15db_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_a15db_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_a15db_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_a15db_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_a15db_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a15db_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a15db_row0_col0" class="data row0 col0" >0.9076</td>
#       <td id="T_a15db_row0_col1" class="data row0 col1" >14114.2429</td>
#       <td id="T_a15db_row0_col2" class="data row0 col2" >0.1625</td>
#       <td id="T_a15db_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_a15db_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_a15db_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# For Cluster = 5
# <style type="text/css">
# </style>
# <table id="T_ef07c" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ef07c_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_ef07c_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_ef07c_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_ef07c_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_ef07c_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_ef07c_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ef07c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ef07c_row0_col0" class="data row0 col0" >0.9076</td>
#       <td id="T_ef07c_row0_col1" class="data row0 col1" >14114.2429</td>
#       <td id="T_ef07c_row0_col2" class="data row0 col2" >0.1625</td>
#       <td id="T_ef07c_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_ef07c_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_ef07c_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]

# %%
#Using PCA

setup(data = data, pca = True, pca_method = 'linear', verbose=False)

print("For Cluster = 3")
x = create_model('meanshift', num_clusters = 3)

print("For Cluster = 4")
x = create_model('meanshift', num_clusters = 4)

print("For Cluster = 5")
x = create_model('meanshift', num_clusters = 5)
# Out:
# For Cluster = 3
# <style type="text/css">
# </style>
# <table id="T_29c29" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_29c29_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_29c29_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_29c29_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_29c29_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_29c29_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_29c29_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_29c29_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_29c29_row0_col0" class="data row0 col0" >0.3644</td>
#       <td id="T_29c29_row0_col1" class="data row0 col1" >54.7541</td>
#       <td id="T_29c29_row0_col2" class="data row0 col2" >0.5765</td>
#       <td id="T_29c29_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_29c29_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_29c29_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# For Cluster = 4
# <style type="text/css">
# </style>
# <table id="T_212c9" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_212c9_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_212c9_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_212c9_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_212c9_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_212c9_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_212c9_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_212c9_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_212c9_row0_col0" class="data row0 col0" >0.3644</td>
#       <td id="T_212c9_row0_col1" class="data row0 col1" >54.7541</td>
#       <td id="T_212c9_row0_col2" class="data row0 col2" >0.5765</td>
#       <td id="T_212c9_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_212c9_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_212c9_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# For Cluster = 5
# <style type="text/css">
# </style>
# <table id="T_a02a3" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a02a3_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_a02a3_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_a02a3_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_a02a3_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_a02a3_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_a02a3_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a02a3_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a02a3_row0_col0" class="data row0 col0" >0.3644</td>
#       <td id="T_a02a3_row0_col1" class="data row0 col1" >54.7541</td>
#       <td id="T_a02a3_row0_col2" class="data row0 col2" >0.5765</td>
#       <td id="T_a02a3_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_a02a3_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_a02a3_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]

# %%
#Using T+N

setup(data = data, transformation = True, normalize = True,
      normalize_method = 'zscore', transformation_method = 'yeo-johnson', verbose=False)

print("For Cluster = 3")
x = create_model('meanshift', num_clusters = 3)

print("For Cluster = 4")
x = create_model('meanshift', num_clusters = 4)

print("For Cluster = 5")
x = create_model('meanshift', num_clusters = 5)
# Out:
# For Cluster = 3
# <style type="text/css">
# </style>
# <table id="T_2e79a" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2e79a_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_2e79a_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_2e79a_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_2e79a_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_2e79a_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_2e79a_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2e79a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_2e79a_row0_col0" class="data row0 col0" >0.3461</td>
#       <td id="T_2e79a_row0_col1" class="data row0 col1" >17.4754</td>
#       <td id="T_2e79a_row0_col2" class="data row0 col2" >1.0571</td>
#       <td id="T_2e79a_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_2e79a_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_2e79a_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# For Cluster = 4
# <style type="text/css">
# </style>
# <table id="T_47392" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_47392_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_47392_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_47392_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_47392_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_47392_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_47392_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_47392_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_47392_row0_col0" class="data row0 col0" >0.3461</td>
#       <td id="T_47392_row0_col1" class="data row0 col1" >17.4754</td>
#       <td id="T_47392_row0_col2" class="data row0 col2" >1.0571</td>
#       <td id="T_47392_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_47392_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_47392_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# For Cluster = 5
# <style type="text/css">
# </style>
# <table id="T_86eff" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_86eff_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_86eff_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_86eff_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_86eff_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_86eff_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_86eff_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_86eff_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_86eff_row0_col0" class="data row0 col0" >0.3461</td>
#       <td id="T_86eff_row0_col1" class="data row0 col1" >17.4754</td>
#       <td id="T_86eff_row0_col2" class="data row0 col2" >1.0571</td>
#       <td id="T_86eff_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_86eff_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_86eff_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]

# %%
#Using T+N+PCA

setup(data = data, transformation = True, normalize = True, pca = True,
      normalize_method = 'zscore',
      transformation_method = 'yeo-johnson',
      pca_method = 'linear', verbose=False)

print("For Cluster = 3")
x = create_model('meanshift', num_clusters = 3)

print("For Cluster = 4")
x = create_model('meanshift', num_clusters = 4)

print("For Cluster = 5")
x = create_model('meanshift', num_clusters = 5)
# Out:
# For Cluster = 3
# <style type="text/css">
# </style>
# <table id="T_2e426" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2e426_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_2e426_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_2e426_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_2e426_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_2e426_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_2e426_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2e426_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_2e426_row0_col0" class="data row0 col0" >0.3461</td>
#       <td id="T_2e426_row0_col1" class="data row0 col1" >17.4754</td>
#       <td id="T_2e426_row0_col2" class="data row0 col2" >1.0571</td>
#       <td id="T_2e426_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_2e426_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_2e426_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# For Cluster = 4
# <style type="text/css">
# </style>
# <table id="T_5b29e" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5b29e_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_5b29e_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_5b29e_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_5b29e_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_5b29e_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_5b29e_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5b29e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_5b29e_row0_col0" class="data row0 col0" >0.3461</td>
#       <td id="T_5b29e_row0_col1" class="data row0 col1" >17.4754</td>
#       <td id="T_5b29e_row0_col2" class="data row0 col2" >1.0571</td>
#       <td id="T_5b29e_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_5b29e_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_5b29e_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# For Cluster = 5
# <style type="text/css">
# </style>
# <table id="T_18ec7" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_18ec7_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_18ec7_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_18ec7_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_18ec7_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_18ec7_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_18ec7_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_18ec7_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_18ec7_row0_col0" class="data row0 col0" >0.3461</td>
#       <td id="T_18ec7_row0_col1" class="data row0 col1" >17.4754</td>
#       <td id="T_18ec7_row0_col2" class="data row0 col2" >1.0571</td>
#       <td id="T_18ec7_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_18ec7_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_18ec7_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
